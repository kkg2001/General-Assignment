# %%
    ST:ON="Device is ON"
    ST:OFF="Device is OFF"
    device=[[139681125603136], 
           [139681125603134],
           [139681125603178],
           [139681125603136], 
           [139681125603191], 
           [139681125603191],
           [139681125603136], 
           [139681125603136], 
           [139681125603191], 
           [139681125603178]]
    Duration=("Jul 11 16:11:51:490"
              "Jul 11 16:11:51:490",
              "Jul 11 16:11:52:452", 
              "Jul 11 16:11:54:661", 
              "Jul 11 16:11:55:079", 
              "Jul 11 16:11:55:083",
              "Jul 11 16:11:56:067", 
              "Jul 11 16:11:58:500", 
              "Jul 11 16:11:58:242", 
              "Jul 11 16:12:10:101")
    list=[device,Duration]
    for i in list:
              
                for j in list:
 
            
                if i.device  == j.device:
              
                time=j.Duration-i.Duration        
    print("the device ID was %d for %d seconds",device,time)
# Out:
#   File "<ipython-input-152-b2ddfdf39edd>", line 30
#     if i.device  == j.device:
#     ^
# IndentationError: expected an indented block
